# %% [markdown]
# # Find each firm's respective industry

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import urllib3
# import re2
import regex
import re
import io
from requests.exceptions import HTTPError
from IPython.core.display import HTML

# %%
FirmNames_Tickers = pd.read_csv("../data/US_Tickers.csv")
FirmNames_Tickers
# Out:
#      ticker
# 0      TRUE
# 1      ZYXI
# 2        ZY
# 3       ZWS
# 4       ZVO
# ...     ...
# 3467   TIVO
# 3468    EQT
# 3469    AYR
# 3470   SUNS
# 3471    WPX
#
# [3472 rows x 1 columns]

# %%
FirmNames_Tickers['ticker'] = FirmNames_Tickers['ticker'].astype(str)
FirmNames_Tickers
# Out:
#      ticker
# 0      TRUE
# 1      ZYXI
# 2        ZY
# 3       ZWS
# 4       ZVO
# ...     ...
# 3467   TIVO
# 3468    EQT
# 3469    AYR
# 3470   SUNS
# 3471    WPX
#
# [3472 rows x 1 columns]

# %%
frameList=[]
 
for i in range(3448,len(FirmNames_Tickers['ticker'])):
    Ticker_Feed =  f'{FirmNames_Tickers["ticker"][i]}'  
    frameList.append(yf.Ticker(Ticker_Feed).info.get('industry'))
    
# Industry_frameList = pd.concat(frameList)
# Industry_frameList
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PYXX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PYXX&crumb=xsoUcQkHgfj
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/0INF.L?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=0INF.L&crumb=xsoUcQkHgfj

# %%
FirmNames_Tickers[3448:]
# Out:
#       ticker
# 3448      AA
# 3449       A
# 3450   NTXVF
# 3451     LIF
# 3452    SVRA
# 3453    RSLS
# 3454    TRMT
# 3455    DNKN
# 3456    CTYP
# 3457     RBB
# 3458     NYQ
# 3459    VOLT
# 3460      GV
# 3461    NRUC
# 3462    PYXX
# 3463  0INF.L
# 3464    FRSH
# 3465     KEM
# 3466    HARV
# 3467    TIVO
# 3468     EQT
# 3469     AYR
# 3470    SUNS
# 3471     WPX

# %%
frameList
# Out:
# ['Aluminum',
#  None,
#  'Auto Parts',
#  'Software - Application',
#  'Biotechnology',
#  'Medical Devices',
#  None,
#  None,
#  'Banks - Regional',
#  'Banks - Regional',
#  None,
#  None,
#  'Education & Training Services',
#  None,
#  None,
#  None,
#  'Software - Application',
#  None,
#  None,
#  None,
#  'Oil & Gas E&P',
#  None,
#  'REIT - Mortgage',
#  None]

# %%
for i in range(3440,len(FirmNames_Tickers['ticker'])):
    Ticker_Feed =  f'{FirmNames_Tickers["ticker"][i]}'  
    Industry = yf.Ticker(f'{Ticker_Feed}').info.get('industry')
    print(Industry)
# Out:
# REIT - Diversified
# Consumer Electronics
# Specialty Retail
# Building Products & Equipment
# Communication Equipment
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AAN&crumb=xsoUcQkHgfj
# None
# Airlines
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAIC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AAIC&crumb=xsoUcQkHgfj
# None
# Aluminum
# None
# Auto Parts
# Software - Application
# Biotechnology
# Medical Devices
# None
# None
# Banks - Regional
# Banks - Regional
# None
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
Industries = FirmNames_Tickers.apply(lambda x: yf.Ticker(x['ticker']).info.get("Industry"), axis=1)
 
 
 

#dat = yf.Ticker("{ticker}")
#dat.info['Industry']
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZEV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZEV&crumb=xsoUcQkHgfj
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Industries = FirmNames_Tickers.apply(lambda x: yf.Ticker(x['ticker']).info.get("Industry"), axis=1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...
